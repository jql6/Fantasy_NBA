# %%
################################################################################
# Connecting to Yahoo's API

# Remember to use `shift` + `tab` to see function parameters

# This makes jupyter notebook output everything instead of just the last output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Loading libraries
import numpy as np
import pandas as pd

import json
from pathlib import Path

print("Finished importing")
# Out:
# Finished importing

# %%
"""
How to get your consumer key and consumer secret:

Go to: https://developer.yahoo.com/apps/create/

Create your app; you can set the Redirect URI to "http://localhost:8888"
Also, check the box for Fantasy Sports

Go to: https://developer.yahoo.com/apps and open the app you just created.

You should now see the Client ID/Consumer Key & Client Secret/Consumer Secret
"""

# %%
def get_yahoo_game_key(path_to_private, sports_league):
    """
    Function that returns the game key for the sports league you want.
    
    Arguments:
    path_to_private | str (string)
    The path to your `private.json` file. This file should contain your consumer
    key and consumer secret. It should look like this:
    ```
    {
      "consumer_key": "ENTER_CONSUMER_KEY_STRING",
      "consumer_secret": "ENTER_CONSUMER_SECRET_STRING"
    }
    ```
    
    sports_league | str (string)
    The string for the league you want data from. For example if you want
    basketball, then this string should be "nba".
    
    Returns:
    A string containing your game key.
    """
    
    oauth = OAuth2(consumer_key = None, consumer_secret = None,
                  from_file = path_to_private)
    
    if not oauth.token_is_valid():
        oauth.refresh_access_token()
        
    yahoo_url = ('https://fantasysports.yahooapis.com/fantasy/v2/game/' +
                 sports_league)
    
    # This json contains the game key
    json_response = oauth.session.get(yahoo_url,
                                      params = {"format": "json"}).json()
    # Obtain the game key
    game_key = json_response["fantasy_content"]["game"][0]["game_key"]
    
    return game_key
            
### # Example use
### get_yahoo_game_key(path_to_private = "./private.json",
###                    sports_league = "nba")
# Out:
# '402'

# %%
from yahoo_oauth import OAuth2
import json
# Fix this/make it read nicer
oauth = OAuth2(consumer_key = None, consumer_secret = None,
               from_file="./private.json") # access/secret API tokens

if not oauth.token_is_valid():
    oauth.refresh_access_token()

# Find the game key
yahoo_nba_url = 'https://fantasysports.yahooapis.com/fantasy/v2/game/nba'
# This json contains the game key
json_response = oauth.session.get(yahoo_nba_url,
                                  params = {"format": "json"}).json()
# Obtain the game key
game_key = json_response["fantasy_content"]["game"][0]["game_key"]

json_response

# To find your league id, go to https://basketball.fantasysports.yahoo.com/nba
# then click League -> Settings and you'll see the League ID displayed there
league_id = "1157"
# Getting the league info
url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
       game_key + '.l.' + league_id + '/')
response = oauth.session.get(url, params = {"format": "json"})
raw_response = response.json()# Do what you want with the raw JSON
raw_response
# Getting the scoreboard
url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
       game_key + '.l.' + league_id + '/' + 'scoreboard')
response = oauth.session.get(url, params = {"format": "json"})
raw_response = response.json()# Do what you want with the raw JSON
raw_response
# Out:
# {'fantasy_content': {'xml:lang': 'en-US',
#   'yahoo:uri': '/fantasy/v2/game/nba',
#   'game': [{'game_key': '402',
#     'game_id': '402',
#     'name': 'Basketball',
#     'code': 'nba',
#     'type': 'full',
#     'url': 'https://basketball.fantasysports.yahoo.com/nba',
#     'season': '2020',
#     'is_registration_over': 0,
#     'is_game_over': 0,
#     'is_offseason': 0}],
#   'time': '40.174961090088ms',
#   'copyright': 'Data provided by Yahoo! and STATS, LLC',
#   'refresh_rate': '60'}}
# {'fantasy_content': {'xml:lang': 'en-US',
#   'yahoo:uri': '/fantasy/v2/league/402.l.1157/',
#   'league': [{'league_key': '402.l.1157',
#     'league_id': '1157',
#     'name': 'THE BIG 3 LEAGUE',
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/1157',
#     'logo_url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/1646ac273943b6fddbbb8321d4e4d40bdfcbe752ec69129e4a030f6b01b3576c.png',
#     'draft_status': 'postdraft',
#     'num_teams': 12,
#     'edit_key': '2021-03-08',
#     'weekly_deadline': 'intraday',
#     'league_update_timestamp': '1615185672',
#     'scoring_type': 'head',
#     'league_type': 'private',
#     'renew': '395_57193',
#     'renewed': '',
#     'iris_group_chat_id': '',
#     'allow_add_to_dl_extra_pos': 0,
#     'is_pro_league': '0',
#     'is_cash_league': '0',
#     'current_week': 11,
#     'start_week': '1',
#     'start_date': '2020-12-22',
#     'end_week': '19',
#     'end_date': '2021-05-09',
#     'game_code': 'nba',
#     'season': '2020'}],
#   'time': '13.695955276489ms',
#   'copyright': 'Data provided by Yahoo! and STATS, LLC',
#   'refresh_rate': '60'}}
# {'fantasy_content': {'xml:lang': 'en-US',
#   'yahoo:uri': '/fantasy/v2/league/402.l.1157/scoreboard',
#   'league': [{'league_key': '402.l.1157',
#     'league_id': '1157',
#     'name': 'THE BIG 3 LEAGUE',
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/1157',
#     'logo_url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/1646ac273943b6fddbbb8321d4e4d40bdfcbe752ec69129e4a030f6b01b3576c.png',
#     'draft_status': 'postdraft',
#     'num_teams': 12,
#     'edit_key': '2021-03-08',
#     'weekly_deadline': 'intraday',
#     'league_update_timestamp': '1615185672',
#     'scoring_type': 'head',
#     'league_type': 'private',
#     'renew': '395_57193',
#     'renewed': '',
#     'iris_group_chat_id': '',
#     'allow_add_to_dl_extra_pos': 0,
#     'is_pro_league': '0',
#     'is_cash_league': '0',
#     'current_week': 11,
#     'start_week': '1',
#     'start_date': '2020-12-22',
#     'end_week': '19',
#     'end_date': '2021-05-09',
#     'game_code': 'nba',
#     'season': '2020'},
#    {'scoreboard': {'week': 11,
#      '0': {'matchups': {'0': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.12'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.1'},
#               {'team_id': '1'},
#               {'name': "d m's Cool Team"},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/1'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_12_d.png'}}]},
#               [],
#               {'waiver_priority': 6},
#               {'faab_balance': '100'},
#               {'number_of_moves': '13'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '1',
#                   'nickname': 'd m',
#                   'guid': 'Y6UAAWYHH3NVA73GIKFOAOJHC4',
#                   'is_commissioner': '1',
#                   'email': 'terminator543@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '916',
#                   'felo_tier': 'diamond'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '154/322'}},
#                 {'stat': {'stat_id': '5', 'value': '.478'}},
#                 {'stat': {'stat_id': '9007006', 'value': '80/97'}},
#                 {'stat': {'stat_id': '8', 'value': '.825'}},
#                 {'stat': {'stat_id': '10', 'value': '50'}},
#                 {'stat': {'stat_id': '12', 'value': '438'}},
#                 {'stat': {'stat_id': '15', 'value': '177'}},
#                 {'stat': {'stat_id': '16', 'value': '109'}},
#                 {'stat': {'stat_id': '17', 'value': '33'}},
#                 {'stat': {'stat_id': '18', 'value': '22'}},
#                 {'stat': {'stat_id': '19', 'value': '54'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '8'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 23,
#                 'live_games': 0,
#                 'completed_games': 27}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.12'},
#               {'team_id': '12'},
#               {'name': 'Dame of Thrones'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/12'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/730ecfbe4a42752951563edd4e343601ed32daf4a954f6d9a2337b4e63c9c402.jpg'}}]},
#               [],
#               {'waiver_priority': 8},
#               {'faab_balance': '65'},
#               {'number_of_moves': '46'},
#               {'number_of_trades': '5'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '4'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '12',
#                   'nickname': 'Yao',
#                   'guid': 'LTDB7KJENR5ATBNGURILIPL24Y',
#                   'is_commissioner': '1',
#                   'email': 'drgnm7u@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/c02b463f-94d0-4bb2-93a9-19ac5b5a7e1d_64sq.jpg',
#                   'felo_score': '736',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '113/247'}},
#                 {'stat': {'stat_id': '5', 'value': '.457'}},
#                 {'stat': {'stat_id': '9007006', 'value': '51/64'}},
#                 {'stat': {'stat_id': '8', 'value': '.797'}},
#                 {'stat': {'stat_id': '10', 'value': '43'}},
#                 {'stat': {'stat_id': '12', 'value': '320'}},
#                 {'stat': {'stat_id': '15', 'value': '83'}},
#                 {'stat': {'stat_id': '16', 'value': '74'}},
#                 {'stat': {'stat_id': '17', 'value': '21'}},
#                 {'stat': {'stat_id': '18', 'value': '13'}},
#                 {'stat': {'stat_id': '19', 'value': '36'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '1'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 27,
#                 'live_games': 0,
#                 'completed_games': 28}}}]},
#            'count': 2}}}},
#        '1': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.11'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.2'},
#               {'team_id': '2'},
#               {'name': 'Apple Time'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/2'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/57361845924_1fc7f8.jpg'}}]},
#               [],
#               {'waiver_priority': 2},
#               {'faab_balance': '82'},
#               {'number_of_moves': '18'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '2'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '2',
#                   'nickname': 'Randy',
#                   'guid': '7VT5A5VCVQ6TS5NAWIVGDCYTAQ',
#                   'email': 'randysbassi@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '542',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '171/314'}},
#                 {'stat': {'stat_id': '5', 'value': '.545'}},
#                 {'stat': {'stat_id': '9007006', 'value': '89/119'}},
#                 {'stat': {'stat_id': '8', 'value': '.748'}},
#                 {'stat': {'stat_id': '10', 'value': '35'}},
#                 {'stat': {'stat_id': '12', 'value': '466'}},
#                 {'stat': {'stat_id': '15', 'value': '210'}},
#                 {'stat': {'stat_id': '16', 'value': '101'}},
#                 {'stat': {'stat_id': '17', 'value': '22'}},
#                 {'stat': {'stat_id': '18', 'value': '13'}},
#                 {'stat': {'stat_id': '19', 'value': '56'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '4'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 32,
#                 'live_games': 0,
#                 'completed_games': 29}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.11'},
#               {'team_id': '11'},
#               {'name': 'Kawhi of the Tiger'},
#               {'is_owned_by_current_login': 1},
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/11'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/121a83f6ef53e299e67558057e002b53aa430b7846351b9e6840c90891796426.png'}}]},
#               [],
#               {'waiver_priority': 9},
#               {'faab_balance': '98'},
#               {'number_of_moves': '35'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '5'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '11',
#                   'nickname': 'Kawhi',
#                   'guid': 'OKNHTIC6W4RSZZHJC2ZMGSQZXY',
#                   'is_current_login': '1',
#                   'email': 'jlu6fz@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/796e2ed8-c86c-4c31-baab-97c87c746054_64sq.jpg',
#                   'felo_score': '645',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '169/371'}},
#                 {'stat': {'stat_id': '5', 'value': '.456'}},
#                 {'stat': {'stat_id': '9007006', 'value': '70/91'}},
#                 {'stat': {'stat_id': '8', 'value': '.769'}},
#                 {'stat': {'stat_id': '10', 'value': '54'}},
#                 {'stat': {'stat_id': '12', 'value': '462'}},
#                 {'stat': {'stat_id': '15', 'value': '149'}},
#                 {'stat': {'stat_id': '16', 'value': '91'}},
#                 {'stat': {'stat_id': '17', 'value': '25'}},
#                 {'stat': {'stat_id': '18', 'value': '16'}},
#                 {'stat': {'stat_id': '19', 'value': '43'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '5'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 29,
#                 'live_games': 0,
#                 'completed_games': 29}}}]},
#            'count': 2}}}},
#        '2': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '10', 'is_tied': 1}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '18', 'is_tied': 1}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.10'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.3'},
#               {'team_id': '3'},
#               {'name': 'Ayre Keegan'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/3'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/0cbaa0d3bd00d72e1700c34b1ccb21a2e7dfd7a756c53b510ad5175bc55fa48c.jpg'}}]},
#               [],
#               {'waiver_priority': 3},
#               {'faab_balance': '89'},
#               {'number_of_moves': '29'},
#               {'number_of_trades': '3'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '4'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '3',
#                   'nickname': 'Keegan',
#                   'guid': 'WMZXQBOT3EVYV2PUYTASD452JM',
#                   'email': 'keeganayre@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '560',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '168/338'}},
#                 {'stat': {'stat_id': '5', 'value': '.497'}},
#                 {'stat': {'stat_id': '9007006', 'value': '91/107'}},
#                 {'stat': {'stat_id': '8', 'value': '.850'}},
#                 {'stat': {'stat_id': '10', 'value': '35'}},
#                 {'stat': {'stat_id': '12', 'value': '462'}},
#                 {'stat': {'stat_id': '15', 'value': '132'}},
#                 {'stat': {'stat_id': '16', 'value': '118'}},
#                 {'stat': {'stat_id': '17', 'value': '23'}},
#                 {'stat': {'stat_id': '18', 'value': '10'}},
#                 {'stat': {'stat_id': '19', 'value': '64'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '3'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 32,
#                 'live_games': 0,
#                 'completed_games': 30}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.10'},
#               {'team_id': '10'},
#               {'name': 'Kareem Of The Crop'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/10'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56478196195_304fe8.jpg'}}]},
#               [],
#               {'waiver_priority': 5},
#               {'faab_balance': '100'},
#               {'number_of_moves': '8'},
#               {'number_of_trades': '1'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '10',
#                   'nickname': 'Ricardo',
#                   'guid': 'BVYBCZWFHSU3VC2S2AEX42DSE4',
#                   'email': 'kuipers_20@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '583',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '125/250'}},
#                 {'stat': {'stat_id': '5', 'value': '.500'}},
#                 {'stat': {'stat_id': '9007006', 'value': '55/63'}},
#                 {'stat': {'stat_id': '8', 'value': '.873'}},
#                 {'stat': {'stat_id': '10', 'value': '35'}},
#                 {'stat': {'stat_id': '12', 'value': '340'}},
#                 {'stat': {'stat_id': '15', 'value': '104'}},
#                 {'stat': {'stat_id': '16', 'value': '81'}},
#                 {'stat': {'stat_id': '17', 'value': '26'}},
#                 {'stat': {'stat_id': '18', 'value': '10'}},
#                 {'stat': {'stat_id': '19', 'value': '39'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '4'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 25,
#                 'live_games': 0,
#                 'completed_games': 24}}}]},
#            'count': 2}}}},
#        '3': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.4'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.4'},
#               {'team_id': '4'},
#               {'name': 'Barkley Analytica'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/4'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_8.png'}}]},
#               [],
#               {'waiver_priority': 11},
#               {'faab_balance': '90'},
#               {'number_of_moves': '14'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '1'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '4',
#                   'nickname': 'Johnny',
#                   'guid': 'ECOQD76HNLMFYZVWS52NMLKPSY',
#                   'email': 'johnnyliu8866@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '660',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '90/200'}},
#                 {'stat': {'stat_id': '5', 'value': '.450'}},
#                 {'stat': {'stat_id': '9007006', 'value': '39/49'}},
#                 {'stat': {'stat_id': '8', 'value': '.796'}},
#                 {'stat': {'stat_id': '10', 'value': '24'}},
#                 {'stat': {'stat_id': '12', 'value': '243'}},
#                 {'stat': {'stat_id': '15', 'value': '106'}},
#                 {'stat': {'stat_id': '16', 'value': '73'}},
#                 {'stat': {'stat_id': '17', 'value': '10'}},
#                 {'stat': {'stat_id': '18', 'value': '9'}},
#                 {'stat': {'stat_id': '19', 'value': '39'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '1'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 32,
#                 'live_games': 0,
#                 'completed_games': 21}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.9'},
#               {'team_id': '9'},
#               {'name': 'Hugh Jassol'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/9'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4.png'}}]},
#               [],
#               {'waiver_priority': 10},
#               {'faab_balance': '100'},
#               {'number_of_moves': '9'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '1'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '9',
#                   'nickname': 'Mah',
#                   'guid': 'HQGIRGQAAKYXGCQF5FOVPWTARE',
#                   'email': 'brentmah@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '743',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '172/348'}},
#                 {'stat': {'stat_id': '5', 'value': '.494'}},
#                 {'stat': {'stat_id': '9007006', 'value': '57/71'}},
#                 {'stat': {'stat_id': '8', 'value': '.803'}},
#                 {'stat': {'stat_id': '10', 'value': '47'}},
#                 {'stat': {'stat_id': '12', 'value': '448'}},
#                 {'stat': {'stat_id': '15', 'value': '158'}},
#                 {'stat': {'stat_id': '16', 'value': '111'}},
#                 {'stat': {'stat_id': '17', 'value': '30'}},
#                 {'stat': {'stat_id': '18', 'value': '14'}},
#                 {'stat': {'stat_id': '19', 'value': '52'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '8'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 31,
#                 'live_games': 0,
#                 'completed_games': 28}}}]},
#            'count': 2}}}},
#        '4': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.8'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.5'},
#               {'team_id': '5'},
#               {'name': 'Dynasty DK'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/5'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/59601797252_6448bf.jpg'}}]},
#               [],
#               {'waiver_priority': 12},
#               {'faab_balance': '94'},
#               {'number_of_moves': '19'},
#               {'number_of_trades': '3'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '1'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '5',
#                   'nickname': 'devin',
#                   'guid': 'T57X2SEIQ7J36S4735Y3IAUTBY',
#                   'email': 'dapper_13@yahoo.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '842',
#                   'felo_tier': 'platinum'}},
#                 {'manager': {'manager_id': '13',
#                   'nickname': 'Kelvin',
#                   'guid': 'VRQYD4KZAX4RYO2N5DMN56P7L4',
#                   'is_comanager': '1',
#                   'email': 'kelvinramchand@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '681',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '145/268'}},
#                 {'stat': {'stat_id': '5', 'value': '.541'}},
#                 {'stat': {'stat_id': '9007006', 'value': '60/75'}},
#                 {'stat': {'stat_id': '8', 'value': '.800'}},
#                 {'stat': {'stat_id': '10', 'value': '33'}},
#                 {'stat': {'stat_id': '12', 'value': '383'}},
#                 {'stat': {'stat_id': '15', 'value': '133'}},
#                 {'stat': {'stat_id': '16', 'value': '92'}},
#                 {'stat': {'stat_id': '17', 'value': '28'}},
#                 {'stat': {'stat_id': '18', 'value': '13'}},
#                 {'stat': {'stat_id': '19', 'value': '54'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '4'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 26,
#                 'live_games': 0,
#                 'completed_games': 26}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.8'},
#               {'team_id': '8'},
#               {'name': 'Beal Sandwich'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/8'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_3_s.png'}}]},
#               [],
#               {'waiver_priority': 1},
#               {'faab_balance': '29'},
#               {'number_of_moves': '24'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '8',
#                   'nickname': 'Suneal',
#                   'guid': '7N6TLKO7NKKWDSFFJST7SRHFLM',
#                   'email': 'sunealk@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '618',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '146/324'}},
#                 {'stat': {'stat_id': '5', 'value': '.451'}},
#                 {'stat': {'stat_id': '9007006', 'value': '78/101'}},
#                 {'stat': {'stat_id': '8', 'value': '.772'}},
#                 {'stat': {'stat_id': '10', 'value': '42'}},
#                 {'stat': {'stat_id': '12', 'value': '412'}},
#                 {'stat': {'stat_id': '15', 'value': '151'}},
#                 {'stat': {'stat_id': '16', 'value': '82'}},
#                 {'stat': {'stat_id': '17', 'value': '35'}},
#                 {'stat': {'stat_id': '18', 'value': '10'}},
#                 {'stat': {'stat_id': '19', 'value': '42'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '5'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 31,
#                 'live_games': 0,
#                 'completed_games': 28}}}]},
#            'count': 2}}}},
#        '5': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.7'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.7'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.7'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.7'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.6'},
#               {'team_id': '6'},
#               {'name': 'Boj Bomb'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/6'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/58c971ba6d3aa8d0ef20626ca43c761f60d04cbf4a752d9af288c2078d747525.png'}}]},
#               [],
#               {'waiver_priority': 7},
#               {'faab_balance': '14'},
#               {'number_of_moves': '25'},
#               {'number_of_trades': '4'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '3'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '6',
#                   'nickname': 'Sameer',
#                   'guid': 'VEGTVZJJYZWRWXKC5SPHGCX7HQ',
#                   'is_commissioner': '1',
#                   'email': 'sameerkamboj03@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '758',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '135/281'}},
#                 {'stat': {'stat_id': '5', 'value': '.480'}},
#                 {'stat': {'stat_id': '9007006', 'value': '64/89'}},
#                 {'stat': {'stat_id': '8', 'value': '.719'}},
#                 {'stat': {'stat_id': '10', 'value': '27'}},
#                 {'stat': {'stat_id': '12', 'value': '361'}},
#                 {'stat': {'stat_id': '15', 'value': '149'}},
#                 {'stat': {'stat_id': '16', 'value': '105'}},
#                 {'stat': {'stat_id': '17', 'value': '26'}},
#                 {'stat': {'stat_id': '18', 'value': '10'}},
#                 {'stat': {'stat_id': '19', 'value': '47'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '5'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 31,
#                 'live_games': 0,
#                 'completed_games': 26}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.7'},
#               {'team_id': '7'},
#               {'name': "Garry's Team"},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/7'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4_g.png'}}]},
#               [],
#               {'waiver_priority': 4},
#               {'faab_balance': '100'},
#               {'number_of_moves': '6'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '7',
#                   'nickname': 'Garry',
#                   'guid': 'IZ7JPVDPSHOJG22ZT4HLYJAE24',
#                   'email': 'gurvinder_wadhwa@yahoo.ca',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '516',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '83/170'}},
#                 {'stat': {'stat_id': '5', 'value': '.488'}},
#                 {'stat': {'stat_id': '9007006', 'value': '21/24'}},
#                 {'stat': {'stat_id': '8', 'value': '.875'}},
#                 {'stat': {'stat_id': '10', 'value': '30'}},
#                 {'stat': {'stat_id': '12', 'value': '217'}},
#                 {'stat': {'stat_id': '15', 'value': '53'}},
#                 {'stat': {'stat_id': '16', 'value': '36'}},
#                 {'stat': {'stat_id': '17', 'value': '14'}},
#                 {'stat': {'stat_id': '18', 'value': '7'}},
#                 {'stat': {'stat_id': '19', 'value': '24'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '4'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 22,
#                 'live_games': 0,
#                 'completed_games': 23}}}]},
#            'count': 2}}}},
#        'count': 6}}}}],
#   'time': '425.06194114685ms',
#   'copyright': 'Data provided by Yahoo! and STATS, LLC',
#   'refresh_rate': '60'}}

# %%
# Writing a json file
with open("fantasy_league" + ".json", "w") as f:
            json.dump(raw_response, f)
