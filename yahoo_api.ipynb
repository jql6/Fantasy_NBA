# %%
################################################################################
# Connecting to Yahoo's API

# Remember to use `shift` + `tab` to see function parameters

# This makes jupyter notebook output everything instead of just the last output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Loading libraries
import numpy as np
import pandas as pd

import json
from pathlib import Path

from yahoo_oauth import OAuth2

print("Finished importing")
# Out:
# Finished importing

# %%
"""
How to get your consumer key and consumer secret:

Go to: https://developer.yahoo.com/apps/create/

Create your app; you can set the Redirect URI to "http://localhost:8888"
Also, check the box for Fantasy Sports

Go to: https://developer.yahoo.com/apps and open the app you just created.

You should now see the Client ID/Consumer Key & Client Secret/Consumer Secret
"""

# %%
def get_yahoo_game_key(yahoo_oauth, sports_league,
                       path_to_private = "./private.json"):
    """
    Function that returns the game key for the sports league you want.
    
    Arguments:
    yahoo_oauth | yahoo_oauth.oauth.OAuth2
    Variable that contains your oauth credentials such as your
    consumer key, consumer secret, and access token.
    
    path_to_private | str (string)
    The path to your `private.json` file. This file should contain your consumer
    key and consumer secret. It should look like this:
    ```
    {
      "consumer_key": "ENTER_CONSUMER_KEY_STRING",
      "consumer_secret": "ENTER_CONSUMER_SECRET_STRING"
    }
    ```
    
    sports_league | str (string)
    The string for the league you want data from. For example if you want
    basketball, then this string should be "nba".
    
    Returns:
    A string containing your game key.
    """
    # Refresh the token if needed
    if not yahoo_oauth.token_is_valid():
        yahoo_oauth.refresh_access_token()
        
    yahoo_url = ('https://fantasysports.yahooapis.com/fantasy/v2/game/' +
                 sports_league)
    
    # This json contains the game key
    json_response = yahoo_oauth.session.get(yahoo_url,
                                            params = {"format": "json"}).json()
    # Obtain the game key
    game_key = json_response["fantasy_content"]["game"][0]["game_key"]
    
    return game_key
            
### # Example use
### private_path = "./private.json"
### oauth = OAuth2(consumer_key = None, consumer_secret = None,
###                from_file = private_path)
### get_yahoo_game_key(yahoo_oauth = oauth,
###                    path_to_private = private_path,
###                    sports_league = "nba")

# %%
def get_yahoo_league_info(yahoo_oauth, path_to_private,
                          game_key, league_id):
    """
    Function that returns the game key for the sports league you want.
    
    Arguments:
    yahoo_oauth | yahoo_oauth.oauth.OAuth2
    Variable that contains your oauth credentials such as your
    consumer key, consumer secret, and access token.
    
    path_to_private | str (string)
    The path to your `private.json` file. This file should contain your consumer
    key and consumer secret or access token.
    
    game_key | str (string)
    The string for the game key of your fantasy sport. For example, the
    game key for 'nba' is currently '402'.
    
    league_id | str (string)
    The string for your league's id. To find your league id,
    go to https://basketball.fantasysports.yahoo.com/nba
    then click League -> Settings and you'll see the League ID displayed there
    
    Returns:
    A dictionary of the league's information.
    """
    # Refresh the token if needed
    if not yahoo_oauth.token_is_valid():
        yahoo_oauth.refresh_access_token()
        
    yahoo_url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
       game_key + '.l.' + league_id + '/')
    
    # This json contains the game key
    league_info = yahoo_oauth.session.get(yahoo_url,
                                          params = {"format": "json"}).json()
    return league_info
            
### # Example use
### private_path = "./private.json"
### oauth = OAuth2(consumer_key = None, consumer_secret = None,
###                from_file = private_path)
### my_game_key = get_yahoo_game_key(yahoo_oauth = oauth,
###                                  path_to_private = private_path,
###                                  sports_league = "nba")
### get_yahoo_league_info(yahoo_oauth = oauth,
###                       path_to_private = private_path,
###                       game_key = my_game_key,
###                       league_id = "1157")

# %%
def get_yahoo_teams_dict(yahoo_oauth, game_key, league_id,
                        path_to_private = "./private.json"):
    """
    Function that returns a dictionary between team keys and team
    names.
    
    Arguments:
    yahoo_oauth | yahoo_oauth.oauth.OAuth2
    Variable that contains your oauth credentials such as your
    consumer key, consumer secret, and access token.
    
    game_key | str (string)
    The string for the game key of your fantasy sport. For example, the
    game key for 'nba' is currently '402'.
    
    league_id | str (string)
    The string for your league's id. To find your league id,
    go to https://basketball.fantasysports.yahoo.com/nba
    then click League -> Settings and you'll see the League ID displayed there
    
    path_to_private | str (string)
    The path to your `private.json` file. This file should contain your consumer
    key and consumer secret or access token.
    
    Returns:
    A dictionary between team keys and team names.
    """
    # Refresh the token if needed
    if not yahoo_oauth.token_is_valid():
        yahoo_oauth.refresh_access_token()
        
    yahoo_url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
       game_key + '.l.' + league_id + '/standings')
    
    # This json contains the game key
    teams_info = yahoo_oauth.session.get(yahoo_url,
                                         params = {"format": "json"}).json()
    
    return teams_info
            
# Example use
private_path = "./private.json"
oauth = OAuth2(consumer_key = None, consumer_secret = None,
               from_file = private_path)
my_game_key = get_yahoo_game_key(yahoo_oauth = oauth,
                                 sports_league = "nba")
get_yahoo_teams_dict(yahoo_oauth = oauth,
                     game_key = my_game_key,
                     league_id = "1157")
# Out:
# [2021-03-12 08:44:00,915 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2021-03-12 08:44:00,920 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 77597.29463005066
# [2021-03-12 08:44:00,921 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN HAS EXPIRED
# [2021-03-12 08:44:00,924 DEBUG] [yahoo_oauth.oauth.refresh_access_token] REFRESHING TOKEN
# [2021-03-12 08:44:01,081 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 0.15581989288330078
# [2021-03-12 08:44:01,082 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 08:44:01,386 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 0.4606139659881592
# [2021-03-12 08:44:01,387 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# {'fantasy_content': {'xml:lang': 'en-US',
#   'yahoo:uri': '/fantasy/v2/league/402.l.1157/standings',
#   'league': [{'league_key': '402.l.1157',
#     'league_id': '1157',
#     'name': 'THE BIG 3 LEAGUE',
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/1157',
#     'logo_url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/1646ac273943b6fddbbb8321d4e4d40bdfcbe752ec69129e4a030f6b01b3576c.png',
#     'draft_status': 'postdraft',
#     'num_teams': 12,
#     'edit_key': '2021-03-12',
#     'weekly_deadline': 'intraday',
#     'league_update_timestamp': '1615532914',
#     'scoring_type': 'head',
#     'league_type': 'private',
#     'renew': '395_57193',
#     'renewed': '',
#     'iris_group_chat_id': '',
#     'allow_add_to_dl_extra_pos': 0,
#     'is_pro_league': '0',
#     'is_cash_league': '0',
#     'current_week': 11,
#     'start_week': '1',
#     'start_date': '2020-12-22',
#     'end_week': '19',
#     'end_date': '2021-05-09',
#     'game_code': 'nba',
#     'season': '2020'},
#    {'standings': [{'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.12'},
#           {'team_id': '12'},
#           {'name': 'Dame of Thrones'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/12'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/730ecfbe4a42752951563edd4e343601ed32daf4a954f6d9a2337b4e63c9c402.jpg'}}]},
#           [],
#           {'waiver_priority': 8},
#           {'faab_balance': '65'},
#           {'number_of_moves': '47'},
#           {'number_of_trades': '5'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '5'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '12',
#               'nickname': 'Yao',
#               'guid': 'LTDB7KJENR5ATBNGURILIPL24Y',
#               'is_commissioner': '1',
#               'email': 'drgnm7u@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/c02b463f-94d0-4bb2-93a9-19ac5b5a7e1d_64sq.jpg',
#               'felo_score': '736',
#               'felo_tier': 'gold'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2702/5847'}},
#             {'stat': {'stat_id': '5', 'value': '.462'}},
#             {'stat': {'stat_id': '9007006', 'value': '1160/1395'}},
#             {'stat': {'stat_id': '8', 'value': '.832'}},
#             {'stat': {'stat_id': '10', 'value': '934'}},
#             {'stat': {'stat_id': '12', 'value': '7498'}},
#             {'stat': {'stat_id': '15', 'value': '2551'}},
#             {'stat': {'stat_id': '16', 'value': '1807'}},
#             {'stat': {'stat_id': '17', 'value': '456'}},
#             {'stat': {'stat_id': '18', 'value': '178'}},
#             {'stat': {'stat_id': '19', 'value': '868'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '1',
#            'playoff_seed': '1',
#            'outcome_totals': {'wins': '57',
#             'losses': '32',
#             'ties': '1',
#             'percentage': '.639'},
#            'games_back': '-'}}]},
#        '1': {'team': [[{'team_key': '402.l.1157.t.6'},
#           {'team_id': '6'},
#           {'name': 'Boj Bomb'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/6'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/58c971ba6d3aa8d0ef20626ca43c761f60d04cbf4a752d9af288c2078d747525.png'}}]},
#           [],
#           {'waiver_priority': 7},
#           {'faab_balance': '14'},
#           {'number_of_moves': '26'},
#           {'number_of_trades': '4'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '4'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '6',
#               'nickname': 'Sameer',
#               'guid': 'VEGTVZJJYZWRWXKC5SPHGCX7HQ',
#               'is_commissioner': '1',
#               'email': 'sameerkamboj03@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '758',
#               'felo_tier': 'gold'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2616/5301'}},
#             {'stat': {'stat_id': '5', 'value': '.493'}},
#             {'stat': {'stat_id': '9007006', 'value': '1237/1590'}},
#             {'stat': {'stat_id': '8', 'value': '.778'}},
#             {'stat': {'stat_id': '10', 'value': '564'}},
#             {'stat': {'stat_id': '12', 'value': '7033'}},
#             {'stat': {'stat_id': '15', 'value': '2766'}},
#             {'stat': {'stat_id': '16', 'value': '1692'}},
#             {'stat': {'stat_id': '17', 'value': '371'}},
#             {'stat': {'stat_id': '18', 'value': '378'}},
#             {'stat': {'stat_id': '19', 'value': '960'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '2',
#            'playoff_seed': '2',
#            'outcome_totals': {'wins': '51',
#             'losses': '38',
#             'ties': '1',
#             'percentage': '.572'},
#            'games_back': '6'}}]},
#        '2': {'team': [[{'team_key': '402.l.1157.t.8'},
#           {'team_id': '8'},
#           {'name': 'Beal Sandwich'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/8'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_3_s.png'}}]},
#           [],
#           {'waiver_priority': 1},
#           {'faab_balance': '29'},
#           {'number_of_moves': '24'},
#           {'number_of_trades': '2'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '0'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '8',
#               'nickname': 'Suneal',
#               'guid': '7N6TLKO7NKKWDSFFJST7SRHFLM',
#               'email': 'sunealk@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '618',
#               'felo_tier': 'silver'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2649/5409'}},
#             {'stat': {'stat_id': '5', 'value': '.490'}},
#             {'stat': {'stat_id': '9007006', 'value': '1212/1561'}},
#             {'stat': {'stat_id': '8', 'value': '.776'}},
#             {'stat': {'stat_id': '10', 'value': '635'}},
#             {'stat': {'stat_id': '12', 'value': '7145'}},
#             {'stat': {'stat_id': '15', 'value': '2806'}},
#             {'stat': {'stat_id': '16', 'value': '1343'}},
#             {'stat': {'stat_id': '17', 'value': '416'}},
#             {'stat': {'stat_id': '18', 'value': '350'}},
#             {'stat': {'stat_id': '19', 'value': '826'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '3',
#            'playoff_seed': '3',
#            'outcome_totals': {'wins': '49',
#             'losses': '39',
#             'ties': '2',
#             'percentage': '.556'},
#            'games_back': '7.5'}}]},
#        '3': {'team': [[{'team_key': '402.l.1157.t.5'},
#           {'team_id': '5'},
#           {'name': 'Dynasty DK'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/5'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/59601797252_6448bf.jpg'}}]},
#           [],
#           {'waiver_priority': 12},
#           {'faab_balance': '94'},
#           {'number_of_moves': '20'},
#           {'number_of_trades': '3'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '2'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '5',
#               'nickname': 'devin',
#               'guid': 'T57X2SEIQ7J36S4735Y3IAUTBY',
#               'email': 'dapper_13@yahoo.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '842',
#               'felo_tier': 'platinum'}},
#             {'manager': {'manager_id': '13',
#               'nickname': 'Kelvin',
#               'guid': 'VRQYD4KZAX4RYO2N5DMN56P7L4',
#               'is_comanager': '1',
#               'email': 'kelvinramchand@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '681',
#               'felo_tier': 'silver'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2713/5681'}},
#             {'stat': {'stat_id': '5', 'value': '.478'}},
#             {'stat': {'stat_id': '9007006', 'value': '1188/1578'}},
#             {'stat': {'stat_id': '8', 'value': '.753'}},
#             {'stat': {'stat_id': '10', 'value': '708'}},
#             {'stat': {'stat_id': '12', 'value': '7322'}},
#             {'stat': {'stat_id': '15', 'value': '2627'}},
#             {'stat': {'stat_id': '16', 'value': '1420'}},
#             {'stat': {'stat_id': '17', 'value': '446'}},
#             {'stat': {'stat_id': '18', 'value': '274'}},
#             {'stat': {'stat_id': '19', 'value': '843'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '4',
#            'playoff_seed': '4',
#            'outcome_totals': {'wins': '49',
#             'losses': '41',
#             'ties': 0,
#             'percentage': '.544'},
#            'games_back': '8.5'}}]},
#        '4': {'team': [[{'team_key': '402.l.1157.t.9'},
#           {'team_id': '9'},
#           {'name': 'Hugh Jassol'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/9'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4.png'}}]},
#           [],
#           {'waiver_priority': 10},
#           {'faab_balance': '100'},
#           {'number_of_moves': '9'},
#           {'number_of_trades': 0},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '1'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '9',
#               'nickname': 'Mah',
#               'guid': 'HQGIRGQAAKYXGCQF5FOVPWTARE',
#               'email': 'brentmah@hotmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '743',
#               'felo_tier': 'gold'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2638/5567'}},
#             {'stat': {'stat_id': '5', 'value': '.474'}},
#             {'stat': {'stat_id': '9007006', 'value': '1103/1413'}},
#             {'stat': {'stat_id': '8', 'value': '.781'}},
#             {'stat': {'stat_id': '10', 'value': '775'}},
#             {'stat': {'stat_id': '12', 'value': '7154'}},
#             {'stat': {'stat_id': '15', 'value': '2742'}},
#             {'stat': {'stat_id': '16', 'value': '1459'}},
#             {'stat': {'stat_id': '17', 'value': '444'}},
#             {'stat': {'stat_id': '18', 'value': '279'}},
#             {'stat': {'stat_id': '19', 'value': '802'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '5',
#            'playoff_seed': '5',
#            'outcome_totals': {'wins': '48',
#             'losses': '40',
#             'ties': '2',
#             'percentage': '.544'},
#            'games_back': '8.5'}}]},
#        '5': {'team': [[{'team_key': '402.l.1157.t.4'},
#           {'team_id': '4'},
#           {'name': 'Barkley Analytica'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/4'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_8.png'}}]},
#           [],
#           {'waiver_priority': 11},
#           {'faab_balance': '90'},
#           {'number_of_moves': '15'},
#           {'number_of_trades': 0},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '2'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '4',
#               'nickname': 'Johnny',
#               'guid': 'ECOQD76HNLMFYZVWS52NMLKPSY',
#               'email': 'johnnyliu8866@hotmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '660',
#               'felo_tier': 'silver'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2442/5367'}},
#             {'stat': {'stat_id': '5', 'value': '.455'}},
#             {'stat': {'stat_id': '9007006', 'value': '1010/1212'}},
#             {'stat': {'stat_id': '8', 'value': '.833'}},
#             {'stat': {'stat_id': '10', 'value': '916'}},
#             {'stat': {'stat_id': '12', 'value': '6810'}},
#             {'stat': {'stat_id': '15', 'value': '2427'}},
#             {'stat': {'stat_id': '16', 'value': '1524'}},
#             {'stat': {'stat_id': '17', 'value': '349'}},
#             {'stat': {'stat_id': '18', 'value': '207'}},
#             {'stat': {'stat_id': '19', 'value': '798'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '6',
#            'playoff_seed': '6',
#            'outcome_totals': {'wins': '48',
#             'losses': '42',
#             'ties': 0,
#             'percentage': '.533'},
#            'games_back': '9.5'}}]},
#        '6': {'team': [[{'team_key': '402.l.1157.t.1'},
#           {'team_id': '1'},
#           {'name': "d m's Cool Team"},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/1'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_12_d.png'}}]},
#           [],
#           {'waiver_priority': 6},
#           {'faab_balance': '100'},
#           {'number_of_moves': '13'},
#           {'number_of_trades': 0},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '0'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '1',
#               'nickname': 'd m',
#               'guid': 'Y6UAAWYHH3NVA73GIKFOAOJHC4',
#               'is_commissioner': '1',
#               'email': 'terminator543@hotmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '916',
#               'felo_tier': 'diamond'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2561/5420'}},
#             {'stat': {'stat_id': '5', 'value': '.473'}},
#             {'stat': {'stat_id': '9007006', 'value': '1199/1418'}},
#             {'stat': {'stat_id': '8', 'value': '.846'}},
#             {'stat': {'stat_id': '10', 'value': '806'}},
#             {'stat': {'stat_id': '12', 'value': '7127'}},
#             {'stat': {'stat_id': '15', 'value': '2811'}},
#             {'stat': {'stat_id': '16', 'value': '1769'}},
#             {'stat': {'stat_id': '17', 'value': '412'}},
#             {'stat': {'stat_id': '18', 'value': '332'}},
#             {'stat': {'stat_id': '19', 'value': '862'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '7',
#            'playoff_seed': '7',
#            'outcome_totals': {'wins': '48',
#             'losses': '42',
#             'ties': 0,
#             'percentage': '.533'},
#            'games_back': '9.5'}}]},
#        '7': {'team': [[{'team_key': '402.l.1157.t.11'},
#           {'team_id': '11'},
#           {'name': 'Kawhi of the Tiger'},
#           {'is_owned_by_current_login': 1},
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/11'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/121a83f6ef53e299e67558057e002b53aa430b7846351b9e6840c90891796426.png'}}]},
#           [],
#           {'waiver_priority': 9},
#           {'faab_balance': '98'},
#           {'number_of_moves': '35'},
#           {'number_of_trades': 0},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '5'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '11',
#               'nickname': 'Kawhi',
#               'guid': 'OKNHTIC6W4RSZZHJC2ZMGSQZXY',
#               'is_current_login': '1',
#               'email': 'jlu6fz@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/796e2ed8-c86c-4c31-baab-97c87c746054_64sq.jpg',
#               'felo_score': '645',
#               'felo_tier': 'silver'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2358/4984'}},
#             {'stat': {'stat_id': '5', 'value': '.473'}},
#             {'stat': {'stat_id': '9007006', 'value': '1214/1508'}},
#             {'stat': {'stat_id': '8', 'value': '.805'}},
#             {'stat': {'stat_id': '10', 'value': '720'}},
#             {'stat': {'stat_id': '12', 'value': '6650'}},
#             {'stat': {'stat_id': '15', 'value': '2375'}},
#             {'stat': {'stat_id': '16', 'value': '1155'}},
#             {'stat': {'stat_id': '17', 'value': '399'}},
#             {'stat': {'stat_id': '18', 'value': '346'}},
#             {'stat': {'stat_id': '19', 'value': '691'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '8',
#            'playoff_seed': '8',
#            'outcome_totals': {'wins': '43',
#             'losses': '46',
#             'ties': '1',
#             'percentage': '.483'},
#            'games_back': '14'}}]},
#        '8': {'team': [[{'team_key': '402.l.1157.t.3'},
#           {'team_id': '3'},
#           {'name': 'Ayre Keegan'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/3'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/0cbaa0d3bd00d72e1700c34b1ccb21a2e7dfd7a756c53b510ad5175bc55fa48c.jpg'}}]},
#           [],
#           {'waiver_priority': 3},
#           {'faab_balance': '89'},
#           {'number_of_moves': '29'},
#           {'number_of_trades': '3'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '4'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '3',
#               'nickname': 'Keegan',
#               'guid': 'WMZXQBOT3EVYV2PUYTASD452JM',
#               'email': 'keeganayre@hotmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '560',
#               'felo_tier': 'bronze'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2464/5220'}},
#             {'stat': {'stat_id': '5', 'value': '.472'}},
#             {'stat': {'stat_id': '9007006', 'value': '1098/1364'}},
#             {'stat': {'stat_id': '8', 'value': '.805'}},
#             {'stat': {'stat_id': '10', 'value': '677'}},
#             {'stat': {'stat_id': '12', 'value': '6703'}},
#             {'stat': {'stat_id': '15', 'value': '2135'}},
#             {'stat': {'stat_id': '16', 'value': '1687'}},
#             {'stat': {'stat_id': '17', 'value': '407'}},
#             {'stat': {'stat_id': '18', 'value': '176'}},
#             {'stat': {'stat_id': '19', 'value': '821'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '9',
#            'outcome_totals': {'wins': '43',
#             'losses': '46',
#             'ties': '1',
#             'percentage': '.483'},
#            'games_back': '14'}}]},
#        '9': {'team': [[{'team_key': '402.l.1157.t.2'},
#           {'team_id': '2'},
#           {'name': 'Apple Time'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/2'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/57361845924_1fc7f8.jpg'}}]},
#           [],
#           {'waiver_priority': 2},
#           {'faab_balance': '82'},
#           {'number_of_moves': '18'},
#           {'number_of_trades': '2'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '2'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '2',
#               'nickname': 'Randy',
#               'guid': '7VT5A5VCVQ6TS5NAWIVGDCYTAQ',
#               'email': 'randysbassi@gmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '542',
#               'felo_tier': 'bronze'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '2736/5658'}},
#             {'stat': {'stat_id': '5', 'value': '.484'}},
#             {'stat': {'stat_id': '9007006', 'value': '1323/1736'}},
#             {'stat': {'stat_id': '8', 'value': '.762'}},
#             {'stat': {'stat_id': '10', 'value': '655'}},
#             {'stat': {'stat_id': '12', 'value': '7450'}},
#             {'stat': {'stat_id': '15', 'value': '2489'}},
#             {'stat': {'stat_id': '16', 'value': '1661'}},
#             {'stat': {'stat_id': '17', 'value': '353'}},
#             {'stat': {'stat_id': '18', 'value': '249'}},
#             {'stat': {'stat_id': '19', 'value': '934'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '10',
#            'outcome_totals': {'wins': '42',
#             'losses': '48',
#             'ties': 0,
#             'percentage': '.467'},
#            'games_back': '15.5'}}]},
#        '10': {'team': [[{'team_key': '402.l.1157.t.10'},
#           {'team_id': '10'},
#           {'name': 'Kareem Of The Crop'},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/10'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56478196195_304fe8.jpg'}}]},
#           [],
#           {'waiver_priority': 5},
#           {'faab_balance': '100'},
#           {'number_of_moves': '8'},
#           {'number_of_trades': '1'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '0'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '10',
#               'nickname': 'Ricardo',
#               'guid': 'BVYBCZWFHSU3VC2S2AEX42DSE4',
#               'email': 'kuipers_20@hotmail.com',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '583',
#               'felo_tier': 'bronze'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '1943/4175'}},
#             {'stat': {'stat_id': '5', 'value': '.465'}},
#             {'stat': {'stat_id': '9007006', 'value': '783/1007'}},
#             {'stat': {'stat_id': '8', 'value': '.778'}},
#             {'stat': {'stat_id': '10', 'value': '527'}},
#             {'stat': {'stat_id': '12', 'value': '5196'}},
#             {'stat': {'stat_id': '15', 'value': '1872'}},
#             {'stat': {'stat_id': '16', 'value': '1487'}},
#             {'stat': {'stat_id': '17', 'value': '453'}},
#             {'stat': {'stat_id': '18', 'value': '239'}},
#             {'stat': {'stat_id': '19', 'value': '622'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '11',
#            'outcome_totals': {'wins': '35',
#             'losses': '54',
#             'ties': '1',
#             'percentage': '.394'},
#            'games_back': '22'}}]},
#        '11': {'team': [[{'team_key': '402.l.1157.t.7'},
#           {'team_id': '7'},
#           {'name': "Garry's Team"},
#           [],
#           {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/7'},
#           {'team_logos': [{'team_logo': {'size': 'large',
#               'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4_g.png'}}]},
#           [],
#           {'waiver_priority': 4},
#           {'faab_balance': '100'},
#           {'number_of_moves': '6'},
#           {'number_of_trades': '2'},
#           {'roster_adds': {'coverage_type': 'week',
#             'coverage_value': 11,
#             'value': '0'}},
#           [],
#           {'league_scoring_type': 'head'},
#           [],
#           [],
#           {'has_draft_grade': 0},
#           [],
#           [],
#           {'managers': [{'manager': {'manager_id': '7',
#               'nickname': 'Garry',
#               'guid': 'IZ7JPVDPSHOJG22ZT4HLYJAE24',
#               'email': 'gurvinder_wadhwa@yahoo.ca',
#               'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#               'felo_score': '516',
#               'felo_tier': 'bronze'}}]}],
#          {'team_stats': {'coverage_type': 'season',
#            'season': '2020',
#            'stats': [{'stat': {'stat_id': '9004003', 'value': '1971/4261'}},
#             {'stat': {'stat_id': '5', 'value': '.463'}},
#             {'stat': {'stat_id': '9007006', 'value': '792/1069'}},
#             {'stat': {'stat_id': '8', 'value': '.741'}},
#             {'stat': {'stat_id': '10', 'value': '641'}},
#             {'stat': {'stat_id': '12', 'value': '5375'}},
#             {'stat': {'stat_id': '15', 'value': '1846'}},
#             {'stat': {'stat_id': '16', 'value': '1308'}},
#             {'stat': {'stat_id': '17', 'value': '275'}},
#             {'stat': {'stat_id': '18', 'value': '175'}},
#             {'stat': {'stat_id': '19', 'value': '675'}}]},
#           'team_points': {'coverage_type': 'season',
#            'season': '2020',
#            'total': ''}},
#          {'team_standings': {'rank': '12',
#            'outcome_totals': {'wins': '22',
#             'losses': '67',
#             'ties': '1',
#             'percentage': '.250'},
#            'games_back': '35'}}]},
#        'count': 12}}]}],
#   'time': '324.25999641418ms',
#   'copyright': 'Data provided by Yahoo! and STATS, LLC',
#   'refresh_rate': '60'}}

# %%
from yahoo_oauth import OAuth2
import json
# Fix this/make it read nicer
oauth = OAuth2(consumer_key = None, consumer_secret = None,
               from_file="./private.json") # access/secret API tokens

if not oauth.token_is_valid():
    oauth.refresh_access_token()

# Obtain the game key
game_key = get_yahoo_game_key(yahoo_oauth = oauth,
                              path_to_private = "./private.json",
                              sports_league = "nba")

# To find your league id, go to https://basketball.fantasysports.yahoo.com/nba
# then click League -> Settings and you'll see the League ID displayed there
league_id = "1157"
week = "11"
# Getting the scoreboard
url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
       game_key + '.l.' + league_id + '/' + 'scoreboard;week=' + week)
response = oauth.session.get(url, params = {"format": "json"})
raw_response = response.json()# Do what you want with the raw JSON
raw_response
# Out:
# [2021-03-12 08:44:08,237 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2021-03-12 08:44:08,241 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 7.3154168128967285
# [2021-03-12 08:44:08,243 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 08:44:08,255 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 7.3297340869903564
# [2021-03-12 08:44:08,257 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 08:44:08,260 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 7.335144996643066
# [2021-03-12 08:44:08,262 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# {'fantasy_content': {'xml:lang': 'en-US',
#   'yahoo:uri': '/fantasy/v2/league/402.l.1157/scoreboard;week=11',
#   'league': [{'league_key': '402.l.1157',
#     'league_id': '1157',
#     'name': 'THE BIG 3 LEAGUE',
#     'url': 'https://basketball.fantasysports.yahoo.com/nba/1157',
#     'logo_url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/1646ac273943b6fddbbb8321d4e4d40bdfcbe752ec69129e4a030f6b01b3576c.png',
#     'draft_status': 'postdraft',
#     'num_teams': 12,
#     'edit_key': '2021-03-12',
#     'weekly_deadline': 'intraday',
#     'league_update_timestamp': '1615532914',
#     'scoring_type': 'head',
#     'league_type': 'private',
#     'renew': '395_57193',
#     'renewed': '',
#     'iris_group_chat_id': '',
#     'allow_add_to_dl_extra_pos': 0,
#     'is_pro_league': '0',
#     'is_cash_league': '0',
#     'current_week': 11,
#     'start_week': '1',
#     'start_date': '2020-12-22',
#     'end_week': '19',
#     'end_date': '2021-05-09',
#     'game_code': 'nba',
#     'season': '2020'},
#    {'scoreboard': {'week': '11',
#      '0': {'matchups': {'0': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.1'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.12'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.1'},
#               {'team_id': '1'},
#               {'name': "d m's Cool Team"},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/1'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_12_d.png'}}]},
#               [],
#               {'waiver_priority': 6},
#               {'faab_balance': '100'},
#               {'number_of_moves': '13'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '1',
#                   'nickname': 'd m',
#                   'guid': 'Y6UAAWYHH3NVA73GIKFOAOJHC4',
#                   'is_commissioner': '1',
#                   'email': 'terminator543@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '916',
#                   'felo_tier': 'diamond'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '248/501'}},
#                 {'stat': {'stat_id': '5', 'value': '.495'}},
#                 {'stat': {'stat_id': '9007006', 'value': '117/141'}},
#                 {'stat': {'stat_id': '8', 'value': '.830'}},
#                 {'stat': {'stat_id': '10', 'value': '72'}},
#                 {'stat': {'stat_id': '12', 'value': '685'}},
#                 {'stat': {'stat_id': '15', 'value': '265'}},
#                 {'stat': {'stat_id': '16', 'value': '151'}},
#                 {'stat': {'stat_id': '17', 'value': '42'}},
#                 {'stat': {'stat_id': '18', 'value': '35'}},
#                 {'stat': {'stat_id': '19', 'value': '78'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '8'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 14,
#                 'live_games': 0,
#                 'completed_games': 39}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.12'},
#               {'team_id': '12'},
#               {'name': 'Dame of Thrones'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/12'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/730ecfbe4a42752951563edd4e343601ed32daf4a954f6d9a2337b4e63c9c402.jpg'}}]},
#               [],
#               {'waiver_priority': 8},
#               {'faab_balance': '65'},
#               {'number_of_moves': '47'},
#               {'number_of_trades': '5'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '5'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '12',
#                   'nickname': 'Yao',
#                   'guid': 'LTDB7KJENR5ATBNGURILIPL24Y',
#                   'is_commissioner': '1',
#                   'email': 'drgnm7u@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/c02b463f-94d0-4bb2-93a9-19ac5b5a7e1d_64sq.jpg',
#                   'felo_score': '736',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '163/354'}},
#                 {'stat': {'stat_id': '5', 'value': '.460'}},
#                 {'stat': {'stat_id': '9007006', 'value': '64/79'}},
#                 {'stat': {'stat_id': '8', 'value': '.810'}},
#                 {'stat': {'stat_id': '10', 'value': '65'}},
#                 {'stat': {'stat_id': '12', 'value': '455'}},
#                 {'stat': {'stat_id': '15', 'value': '132'}},
#                 {'stat': {'stat_id': '16', 'value': '111'}},
#                 {'stat': {'stat_id': '17', 'value': '28'}},
#                 {'stat': {'stat_id': '18', 'value': '17'}},
#                 {'stat': {'stat_id': '19', 'value': '51'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '1'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 22,
#                 'live_games': 0,
#                 'completed_games': 39}}}]},
#            'count': 2}}}},
#        '1': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.2'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.11'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.11'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.2'},
#               {'team_id': '2'},
#               {'name': 'Apple Time'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/2'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/57361845924_1fc7f8.jpg'}}]},
#               [],
#               {'waiver_priority': 2},
#               {'faab_balance': '82'},
#               {'number_of_moves': '18'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '2'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '2',
#                   'nickname': 'Randy',
#                   'guid': '7VT5A5VCVQ6TS5NAWIVGDCYTAQ',
#                   'email': 'randysbassi@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '542',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '232/443'}},
#                 {'stat': {'stat_id': '5', 'value': '.524'}},
#                 {'stat': {'stat_id': '9007006', 'value': '119/164'}},
#                 {'stat': {'stat_id': '8', 'value': '.726'}},
#                 {'stat': {'stat_id': '10', 'value': '44'}},
#                 {'stat': {'stat_id': '12', 'value': '627'}},
#                 {'stat': {'stat_id': '15', 'value': '270'}},
#                 {'stat': {'stat_id': '16', 'value': '129'}},
#                 {'stat': {'stat_id': '17', 'value': '31'}},
#                 {'stat': {'stat_id': '18', 'value': '19'}},
#                 {'stat': {'stat_id': '19', 'value': '86'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '3'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 16,
#                 'live_games': 0,
#                 'completed_games': 40}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.11'},
#               {'team_id': '11'},
#               {'name': 'Kawhi of the Tiger'},
#               {'is_owned_by_current_login': 1},
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/11'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/121a83f6ef53e299e67558057e002b53aa430b7846351b9e6840c90891796426.png'}}]},
#               [],
#               {'waiver_priority': 9},
#               {'faab_balance': '98'},
#               {'number_of_moves': '35'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '5'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '11',
#                   'nickname': 'Kawhi',
#                   'guid': 'OKNHTIC6W4RSZZHJC2ZMGSQZXY',
#                   'is_current_login': '1',
#                   'email': 'jlu6fz@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/796e2ed8-c86c-4c31-baab-97c87c746054_64sq.jpg',
#                   'felo_score': '645',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '242/509'}},
#                 {'stat': {'stat_id': '5', 'value': '.475'}},
#                 {'stat': {'stat_id': '9007006', 'value': '99/126'}},
#                 {'stat': {'stat_id': '8', 'value': '.786'}},
#                 {'stat': {'stat_id': '10', 'value': '80'}},
#                 {'stat': {'stat_id': '12', 'value': '663'}},
#                 {'stat': {'stat_id': '15', 'value': '194'}},
#                 {'stat': {'stat_id': '16', 'value': '113'}},
#                 {'stat': {'stat_id': '17', 'value': '34'}},
#                 {'stat': {'stat_id': '18', 'value': '22'}},
#                 {'stat': {'stat_id': '19', 'value': '56'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '6'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 19,
#                 'live_games': 0,
#                 'completed_games': 39}}}]},
#            'count': 2}}}},
#        '2': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.3'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.10'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.10'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.3'},
#               {'team_id': '3'},
#               {'name': 'Ayre Keegan'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/3'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/0cbaa0d3bd00d72e1700c34b1ccb21a2e7dfd7a756c53b510ad5175bc55fa48c.jpg'}}]},
#               [],
#               {'waiver_priority': 3},
#               {'faab_balance': '89'},
#               {'number_of_moves': '29'},
#               {'number_of_trades': '3'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '4'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '3',
#                   'nickname': 'Keegan',
#                   'guid': 'WMZXQBOT3EVYV2PUYTASD452JM',
#                   'email': 'keeganayre@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '560',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '229/457'}},
#                 {'stat': {'stat_id': '5', 'value': '.501'}},
#                 {'stat': {'stat_id': '9007006', 'value': '116/138'}},
#                 {'stat': {'stat_id': '8', 'value': '.841'}},
#                 {'stat': {'stat_id': '10', 'value': '46'}},
#                 {'stat': {'stat_id': '12', 'value': '620'}},
#                 {'stat': {'stat_id': '15', 'value': '181'}},
#                 {'stat': {'stat_id': '16', 'value': '161'}},
#                 {'stat': {'stat_id': '17', 'value': '33'}},
#                 {'stat': {'stat_id': '18', 'value': '13'}},
#                 {'stat': {'stat_id': '19', 'value': '77'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '4'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 18,
#                 'live_games': 0,
#                 'completed_games': 41}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.10'},
#               {'team_id': '10'},
#               {'name': 'Kareem Of The Crop'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/10'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56478196195_304fe8.jpg'}}]},
#               [],
#               {'waiver_priority': 5},
#               {'faab_balance': '100'},
#               {'number_of_moves': '8'},
#               {'number_of_trades': '1'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '10',
#                   'nickname': 'Ricardo',
#                   'guid': 'BVYBCZWFHSU3VC2S2AEX42DSE4',
#                   'email': 'kuipers_20@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '583',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '174/375'}},
#                 {'stat': {'stat_id': '5', 'value': '.464'}},
#                 {'stat': {'stat_id': '9007006', 'value': '95/111'}},
#                 {'stat': {'stat_id': '8', 'value': '.856'}},
#                 {'stat': {'stat_id': '10', 'value': '47'}},
#                 {'stat': {'stat_id': '12', 'value': '490'}},
#                 {'stat': {'stat_id': '15', 'value': '146'}},
#                 {'stat': {'stat_id': '16', 'value': '121'}},
#                 {'stat': {'stat_id': '17', 'value': '35'}},
#                 {'stat': {'stat_id': '18', 'value': '18'}},
#                 {'stat': {'stat_id': '19', 'value': '56'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '5'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 21,
#                 'live_games': 0,
#                 'completed_games': 35}}}]},
#            'count': 2}}}},
#        '3': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.4'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.9'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.4'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.4'},
#               {'team_id': '4'},
#               {'name': 'Barkley Analytica'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/4'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_8.png'}}]},
#               [],
#               {'waiver_priority': 11},
#               {'faab_balance': '90'},
#               {'number_of_moves': '15'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '2'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '4',
#                   'nickname': 'Johnny',
#                   'guid': 'ECOQD76HNLMFYZVWS52NMLKPSY',
#                   'email': 'johnnyliu8866@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '660',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '134/311'}},
#                 {'stat': {'stat_id': '5', 'value': '.431'}},
#                 {'stat': {'stat_id': '9007006', 'value': '57/70'}},
#                 {'stat': {'stat_id': '8', 'value': '.814'}},
#                 {'stat': {'stat_id': '10', 'value': '42'}},
#                 {'stat': {'stat_id': '12', 'value': '367'}},
#                 {'stat': {'stat_id': '15', 'value': '159'}},
#                 {'stat': {'stat_id': '16', 'value': '105'}},
#                 {'stat': {'stat_id': '17', 'value': '14'}},
#                 {'stat': {'stat_id': '18', 'value': '14'}},
#                 {'stat': {'stat_id': '19', 'value': '61'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '2'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 22,
#                 'live_games': 0,
#                 'completed_games': 31}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.9'},
#               {'team_id': '9'},
#               {'name': 'Hugh Jassol'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/9'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4.png'}}]},
#               [],
#               {'waiver_priority': 10},
#               {'faab_balance': '100'},
#               {'number_of_moves': '9'},
#               {'number_of_trades': 0},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '1'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '9',
#                   'nickname': 'Mah',
#                   'guid': 'HQGIRGQAAKYXGCQF5FOVPWTARE',
#                   'email': 'brentmah@hotmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '743',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '235/500'}},
#                 {'stat': {'stat_id': '5', 'value': '.470'}},
#                 {'stat': {'stat_id': '9007006', 'value': '98/121'}},
#                 {'stat': {'stat_id': '8', 'value': '.810'}},
#                 {'stat': {'stat_id': '10', 'value': '71'}},
#                 {'stat': {'stat_id': '12', 'value': '639'}},
#                 {'stat': {'stat_id': '15', 'value': '217'}},
#                 {'stat': {'stat_id': '16', 'value': '155'}},
#                 {'stat': {'stat_id': '17', 'value': '46'}},
#                 {'stat': {'stat_id': '18', 'value': '19'}},
#                 {'stat': {'stat_id': '19', 'value': '74'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '7'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 20,
#                 'live_games': 0,
#                 'completed_games': 39}}}]},
#            'count': 2}}}},
#        '4': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.8'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.5'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.8'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.5'},
#               {'team_id': '5'},
#               {'name': 'Dynasty DK'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/5'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/59601797252_6448bf.jpg'}}]},
#               [],
#               {'waiver_priority': 12},
#               {'faab_balance': '94'},
#               {'number_of_moves': '20'},
#               {'number_of_trades': '3'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '2'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '5',
#                   'nickname': 'devin',
#                   'guid': 'T57X2SEIQ7J36S4735Y3IAUTBY',
#                   'email': 'dapper_13@yahoo.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '842',
#                   'felo_tier': 'platinum'}},
#                 {'manager': {'manager_id': '13',
#                   'nickname': 'Kelvin',
#                   'guid': 'VRQYD4KZAX4RYO2N5DMN56P7L4',
#                   'is_comanager': '1',
#                   'email': 'kelvinramchand@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '681',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '196/376'}},
#                 {'stat': {'stat_id': '5', 'value': '.521'}},
#                 {'stat': {'stat_id': '9007006', 'value': '82/105'}},
#                 {'stat': {'stat_id': '8', 'value': '.781'}},
#                 {'stat': {'stat_id': '10', 'value': '46'}},
#                 {'stat': {'stat_id': '12', 'value': '520'}},
#                 {'stat': {'stat_id': '15', 'value': '194'}},
#                 {'stat': {'stat_id': '16', 'value': '127'}},
#                 {'stat': {'stat_id': '17', 'value': '36'}},
#                 {'stat': {'stat_id': '18', 'value': '23'}},
#                 {'stat': {'stat_id': '19', 'value': '63'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '3'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 19,
#                 'live_games': 0,
#                 'completed_games': 36}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.8'},
#               {'team_id': '8'},
#               {'name': 'Beal Sandwich'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/8'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_3_s.png'}}]},
#               [],
#               {'waiver_priority': 1},
#               {'faab_balance': '29'},
#               {'number_of_moves': '24'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '8',
#                   'nickname': 'Suneal',
#                   'guid': '7N6TLKO7NKKWDSFFJST7SRHFLM',
#                   'email': 'sunealk@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '618',
#                   'felo_tier': 'silver'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '198/443'}},
#                 {'stat': {'stat_id': '5', 'value': '.447'}},
#                 {'stat': {'stat_id': '9007006', 'value': '108/137'}},
#                 {'stat': {'stat_id': '8', 'value': '.788'}},
#                 {'stat': {'stat_id': '10', 'value': '52'}},
#                 {'stat': {'stat_id': '12', 'value': '556'}},
#                 {'stat': {'stat_id': '15', 'value': '201'}},
#                 {'stat': {'stat_id': '16', 'value': '118'}},
#                 {'stat': {'stat_id': '17', 'value': '44'}},
#                 {'stat': {'stat_id': '18', 'value': '15'}},
#                 {'stat': {'stat_id': '19', 'value': '61'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '6'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 19,
#                 'live_games': 0,
#                 'completed_games': 40}}}]},
#            'count': 2}}}},
#        '5': {'matchup': {'week': '11',
#          'week_start': '2021-03-01',
#          'week_end': '2021-03-14',
#          'status': 'midevent',
#          'is_playoffs': '0',
#          'is_consolation': '0',
#          'stat_winners': [{'stat_winner': {'stat_id': '5',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '8',
#             'winner_team_key': '402.l.1157.t.7'}},
#           {'stat_winner': {'stat_id': '10',
#             'winner_team_key': '402.l.1157.t.7'}},
#           {'stat_winner': {'stat_id': '12',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '15',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '16',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '17',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '18',
#             'winner_team_key': '402.l.1157.t.6'}},
#           {'stat_winner': {'stat_id': '19',
#             'winner_team_key': '402.l.1157.t.7'}}],
#          '0': {'teams': {'0': {'team': [[{'team_key': '402.l.1157.t.6'},
#               {'team_id': '6'},
#               {'name': 'Boj Bomb'},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/6'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/58c971ba6d3aa8d0ef20626ca43c761f60d04cbf4a752d9af288c2078d747525.png'}}]},
#               [],
#               {'waiver_priority': 7},
#               {'faab_balance': '14'},
#               {'number_of_moves': '26'},
#               {'number_of_trades': '4'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '4'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '6',
#                   'nickname': 'Sameer',
#                   'guid': 'VEGTVZJJYZWRWXKC5SPHGCX7HQ',
#                   'is_commissioner': '1',
#                   'email': 'sameerkamboj03@gmail.com',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '758',
#                   'felo_tier': 'gold'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '212/428'}},
#                 {'stat': {'stat_id': '5', 'value': '.495'}},
#                 {'stat': {'stat_id': '9007006', 'value': '92/121'}},
#                 {'stat': {'stat_id': '8', 'value': '.760'}},
#                 {'stat': {'stat_id': '10', 'value': '42'}},
#                 {'stat': {'stat_id': '12', 'value': '558'}},
#                 {'stat': {'stat_id': '15', 'value': '235'}},
#                 {'stat': {'stat_id': '16', 'value': '152'}},
#                 {'stat': {'stat_id': '17', 'value': '38'}},
#                 {'stat': {'stat_id': '18', 'value': '20'}},
#                 {'stat': {'stat_id': '19', 'value': '72'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '6'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 20,
#                 'live_games': 0,
#                 'completed_games': 39}}}]},
#            '1': {'team': [[{'team_key': '402.l.1157.t.7'},
#               {'team_id': '7'},
#               {'name': "Garry's Team"},
#               [],
#               {'url': 'https://basketball.fantasysports.yahoo.com/nba/1157/7'},
#               {'team_logos': [{'team_logo': {'size': 'large',
#                   'url': 'https://s.yimg.com/cv/apiv2/default/nba/nba_4_g.png'}}]},
#               [],
#               {'waiver_priority': 4},
#               {'faab_balance': '100'},
#               {'number_of_moves': '6'},
#               {'number_of_trades': '2'},
#               {'roster_adds': {'coverage_type': 'week',
#                 'coverage_value': 11,
#                 'value': '0'}},
#               [],
#               {'league_scoring_type': 'head'},
#               [],
#               [],
#               {'has_draft_grade': 0},
#               [],
#               [],
#               {'managers': [{'manager': {'manager_id': '7',
#                   'nickname': 'Garry',
#                   'guid': 'IZ7JPVDPSHOJG22ZT4HLYJAE24',
#                   'email': 'gurvinder_wadhwa@yahoo.ca',
#                   'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#                   'felo_score': '516',
#                   'felo_tier': 'bronze'}}]}],
#              {'team_stats': {'coverage_type': 'week',
#                'week': '11',
#                'stats': [{'stat': {'stat_id': '9004003', 'value': '131/269'}},
#                 {'stat': {'stat_id': '5', 'value': '.487'}},
#                 {'stat': {'stat_id': '9007006', 'value': '30/37'}},
#                 {'stat': {'stat_id': '8', 'value': '.811'}},
#                 {'stat': {'stat_id': '10', 'value': '47'}},
#                 {'stat': {'stat_id': '12', 'value': '339'}},
#                 {'stat': {'stat_id': '15', 'value': '96'}},
#                 {'stat': {'stat_id': '16', 'value': '52'}},
#                 {'stat': {'stat_id': '17', 'value': '19'}},
#                 {'stat': {'stat_id': '18', 'value': '15'}},
#                 {'stat': {'stat_id': '19', 'value': '34'}}]},
#               'team_points': {'coverage_type': 'week',
#                'week': '11',
#                'total': '3'},
#               'team_remaining_games': {'coverage_type': 'week',
#                'week': '11',
#                'total': {'remaining_games': 15,
#                 'live_games': 0,
#                 'completed_games': 32}}}]},
#            'count': 2}}}},
#        'count': 6}}}}],
#   'time': '352.42199897766ms',
#   'copyright': 'Data provided by Yahoo! and STATS, LLC',
#   'refresh_rate': '60'}}

# %%
# Writing a json file
with open("nba_scoreboard_week_11" + ".json", "w") as f:
            json.dump(raw_response, f)

# %%
# How to get current week
private_path = "./private.json"
oauth = OAuth2(consumer_key = None, consumer_secret = None,
               from_file = private_path)
my_game_key = get_yahoo_game_key(yahoo_oauth = oauth,
                                 path_to_private = private_path,
                                 sports_league = "nba")
league_info = get_yahoo_league_info(yahoo_oauth = oauth,
                                    path_to_private = private_path,
                                    game_key = my_game_key,
                                    league_id = "1157")

league_info["fantasy_content"]["league"][0]["current_week"]
league_info["fantasy_content"]["league"][0]["start_week"]
league_info["fantasy_content"]["league"][0]["end_week"]
# Out:
# [2021-03-12 08:44:14,665 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2021-03-12 08:44:14,668 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 13.742491006851196
# [2021-03-12 08:44:14,670 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 08:44:14,675 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 13.749447107315063
# [2021-03-12 08:44:14,675 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 08:44:15,201 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 14.276057958602905
# [2021-03-12 08:44:15,203 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# 11
# '1'
# '19'

# %%
def get_yahoo_scoreboard(yahoo_oauth, week_number,
                         game_key, league_id):
    """
    Function that returns the scoreboard json for the given week.
    
    Arguments:
    yahoo_oauth | yahoo_oauth.oauth.OAuth2
    Variable that contains your oauth credentials such as your
    consumer key, consumer secret, and access token.
    
    week_number | str (string)
    The week number for the scoreboard you want to view. Yahoo can only
    show scoreboards one week at a time.
    
    game_key | str (string)
    The string for the game key of your fantasy sport. For example, the
    game key for 'nba' is currently '402'.
    
    league_id | str (string)
    The string for your league's id. To find your league id,
    go to https://basketball.fantasysports.yahoo.com/nba
    then click League -> Settings and you'll see the League ID displayed there
    
    Returns:
    A dictionary of the week's matchup.
    """
    # Refresh the token if needed
    if not yahoo_oauth.token_is_valid():
        yahoo_oauth.refresh_access_token()
        
    # Getting the scoreboard
    yahoo_url = ('https://fantasysports.yahooapis.com/fantasy/v2/league/' +
                 game_key + '.l.' + league_id + '/' + 'scoreboard;week=' + week_number)
    
    # This json contains the game key
    matchup_info = yahoo_oauth.session.get(yahoo_url,
                                           params = {"format": "json"}).json()
    
    start_week = matchup_info["fantasy_content"]["league"][0]["start_week"]
    end_week = matchup_info["fantasy_content"]["league"][0]["end_week"]

    # Notify user is week_number is out of range
    assert (start_week <= week_number), ("week_number must be >= start week: " +
                                         start_week + ".")
    
    assert week_number <= end_week, ("week_number must be <= end week: " +
                                     end_week + ".")
    
    return matchup_info

### # Example use
### private_path = "./private.json"
### oauth = OAuth2(consumer_key = None, consumer_secret = None,
###                from_file = private_path)
### my_game_key = get_yahoo_game_key(yahoo_oauth = oauth,
###                                  path_to_private = private_path,
###                                  sports_league = "nba")
### 
### get_yahoo_scoreboard(yahoo_oauth = oauth,
###                      week_number = "11",
###                      game_key = my_game_key,
###                      league_id = "1157")

# %%
def get_yahoo_team_dict(scoreboard_json):
    """
    Function that returns a dictionary of a team's key, id, and name.
    
    Arguments:
    yahoo_scoreboard | dict
    Variable that contains the matchup json from `get_yahoo_scoreboard`.
    
    Returns:
    A dictionary with team names as the key and team key and id as values.
    
    Notes:
    The purpose of this is to be able to search a team's key when given a team's
    name. You feed the team key into the `get_yahoo_roster` function.
    """
    
    scoreboard = [d["scoreboard"]
               for d in scoreboard_json["fantasy_content"]["league"]
               if "scoreboard" in d][0]
    all_matchups = scoreboard["0"]["matchups"]
    for i in range(all_matchups["count"]):
        current_matchup = all_matchups[str(i)]["matchup"]["0"]["teams"]
        for j in range(current_matchup["count"]):
            team_key = [d["team_key"]
                for d in current_matchup[str(j)]["team"][0]
                if "team_key" in d][0]
            
            team_name = [d["name"]
                 for d in current_matchup[str(j)]["team"][0]
                 if "name" in d][0]
            
            team_id = [d["team_id"]
                 for d in current_matchup[str(j)]["team"][0]
                 if "team_id" in d][0]
            
            current_team_dict = dict()
            current_team_dict["team_key"] = team_key
            current_team_dict["team_id"] = team_id
            team_dict[team_name] = current_team_dict
            
    return team_dict

# %%
get_yahoo_team_dict(scoreboard_json = yahoo_scoreboard)
# Out:
# {"d m's Cool Team": {'team_key': '402.l.1157.t.1', 'team_id': '1'},
#  'Apple Time': {'team_key': '402.l.1157.t.2', 'team_id': '2'},
#  'Ayre Keegan': {'team_key': '402.l.1157.t.3', 'team_id': '3'},
#  'Barkley Analytica': {'team_key': '402.l.1157.t.4', 'team_id': '4'},
#  'Dynasty DK': {'team_key': '402.l.1157.t.5', 'team_id': '5'},
#  'Boj Bomb': {'team_key': '402.l.1157.t.6', 'team_id': '6'},
#  "Garry's Team": {'team_key': '402.l.1157.t.7', 'team_id': '7'},
#  'Beal Sandwich': {'team_key': '402.l.1157.t.8', 'team_id': '8'},
#  'Hugh Jassol': {'team_key': '402.l.1157.t.9', 'team_id': '9'},
#  'Kareem Of The Crop': {'team_key': '402.l.1157.t.10', 'team_id': '10'},
#  'Kawhi of the Tiger': {'team_key': '402.l.1157.t.11', 'team_id': '11'},
#  'Dame of Thrones': {'team_key': '402.l.1157.t.12', 'team_id': '12'}}

# %%
# Function where you input a week and it returns a variable that
# contains week start, week end, status, team 1 name, team 2 name,
# is_playoffs for every matchup

# %%
def get_yahoo_matchups(scoreboard_json):
    """
    Function that returns a dataframe of the matchup info of a given scoreboard.
    
    Arguments:
    yahoo_scoreboard | dict
    Variable that contains the matchup json from `get_yahoo_scoreboard`.
    
    Returns:
    A dataframe with week start, week end, status, team 1 name, team 2 name,
    and is_playoffs for every matchup
    
    Notes:
    This would be used to figure out which team is facing off which other team
    for any given week
    """
    current_week = scoreboard_json["fantasy_content"]["league"][0]["current_week"]
    
    scoreboard = [d["scoreboard"]
               for d in scoreboard_json["fantasy_content"]["league"]
               if "scoreboard" in d][0]
    all_matchups = scoreboard["0"]["matchups"]
    
    matchup_info = []
    
    for i in range(all_matchups["count"]):
        current_matchup_list = []
        
        selected_matchup = all_matchups[str(i)]["matchup"]
        current_matchup_list.append(selected_matchup["week_start"])
        current_matchup_list.append(selected_matchup["week_end"])
        current_matchup_list.append(selected_matchup["status"])
        current_matchup_list.append(selected_matchup["is_playoffs"])
        current_matchup_list.append(selected_matchup["is_consolation"])
        
        current_matchup = selected_matchup["0"]["teams"]
        for j in range(current_matchup["count"]):
            team_name = [d["name"]
                 for d in current_matchup[str(j)]["team"][0]
                 if "name" in d][0]
            
            current_matchup_list.append(team_name)
        matchup_info.append(current_matchup_list)
    
    column_list = ["week_start", "week_end", "status", "is_playoffs",
                   "is_consolation", "team_1", "team_2"]
    matchup_info_df = pd.DataFrame.from_records(matchup_info, columns = column_list)
            
    return matchup_info_df

# %%
get_yahoo_matchups(yahoo_scoreboard)
# Out:
#    week_start    week_end    status is_playoffs is_consolation  \
# 0  2021-03-01  2021-03-14  midevent           0              0
# 1  2021-03-01  2021-03-14  midevent           0              0
# 2  2021-03-01  2021-03-14  midevent           0              0
# 3  2021-03-01  2021-03-14  midevent           0              0
# 4  2021-03-01  2021-03-14  midevent           0              0
# 5  2021-03-01  2021-03-14  midevent           0              0
#
#               team_1              team_2
# 0    d m's Cool Team     Dame of Thrones
# 1         Apple Time  Kawhi of the Tiger
# 2        Ayre Keegan  Kareem Of The Crop
# 3  Barkley Analytica         Hugh Jassol
# 4         Dynasty DK       Beal Sandwich
# 5           Boj Bomb        Garry's Team

# %%
private_path = "./private.json"
oauth = OAuth2(consumer_key = None, consumer_secret = None,
               from_file = private_path)
my_game_key = get_yahoo_game_key(yahoo_oauth = oauth,
                                 path_to_private = private_path,
                                 sports_league = "nba")

week_11 = get_yahoo_scoreboard(yahoo_oauth = oauth,
                               week_number = "11",
                               game_key = my_game_key,
                               league_id = "1157")

loop_num = 0
chosen_matchup = week_11["fantasy_content"]["league"][1]["scoreboard"]\
                        ["0"]["matchups"][str(loop_num)]["matchup"]

chosen_matchup["week_start"]
chosen_matchup["week_end"]
chosen_matchup["status"]
chosen_matchup["is_playoffs"]
chosen_matchup["is_consolation"]

matchup_teams = chosen_matchup["0"]["teams"]
matchup_teams["0"]["team"][0][0]["team_key"]
matchup_teams["0"]["team"][0][2]["name"]
# Out:
# [2021-03-12 09:33:10,981 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2021-03-12 09:33:10,983 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 2950.0579600334167
# [2021-03-12 09:33:10,985 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 09:33:10,999 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 2950.0719158649445
# [2021-03-12 09:33:11,000 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# [2021-03-12 09:33:12,285 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 2951.359827041626
# [2021-03-12 09:33:12,287 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# '2021-03-01'
# '2021-03-14'
# 'midevent'
# '0'
# '0'
# '402.l.1157.t.1'
# "d m's Cool Team"

# %%
def get_yahoo_roster(yahoo_oauth, team_name):
    """
    Function that returns the roster for a team in the fantasy league.
    
    Arguments:
    yahoo_oauth | yahoo_oauth.oauth.OAuth2
    Variable that contains your oauth credentials such as your
    consumer key, consumer secret, and access token.
    
    team_name | str (string)
    The name of the team's roster that you want to examine.
    
    Returns:
    A dictionary of the week's matchup.
    """
    # Refresh the token if needed
    if not yahoo_oauth.token_is_valid():
        print("Refreshing token")
        yahoo_oauth.refresh_access_token()
        
    # Getting the scoreboard
    yahoo_url = ("https://fantasysports.yahooapis.com/fantasy/v2/team/" +
                 team_name + "/roster/players")
    
    # This gets the team roster json file
    team_roster_json = yahoo_oauth.session.get(yahoo_url,
                                          params = {"format": "json"}).json()
################################################################################
    team_roster = team_roster_json["fantasy_content"]["team"][1]["roster"]
    owning_team = team_roster_json["fantasy_content"]["team"][0][2]["name"]
    roster_size = team_roster["0"]["players"]["count"]
    
    roster_list = []
        
    for player_num in range(0, int(roster_size)):
        df_row = []
        num_string = str(player_num)
        # Full name
        player_dict_list = team_roster["0"]["players"][num_string]["player"][0]
        full_name = [d["name"] for d in player_dict_list if "name" in d][0]["full"]
        df_row.append(full_name)
        
        # Team abbreviation
        team_abbreviation = [d["editorial_team_full_name"] for d in player_dict_list
                             if "editorial_team_full_name" in d][0]
        df_row.append(team_abbreviation)
        
        # List of positions
        all_positions = [d["eligible_positions"] for d in player_dict_list
                         if "eligible_positions" in d][0]
        # Available positions
        all_positions = [pos["position"] for pos in all_positions]
        df_row.append(all_positions)
        
        # Injury status
        try:
            injury_status = [d["status"] for d in player_dict_list if "status" in d][0]
        except:
            injury_status = "NONE"
        
        df_row.append(injury_status)
        
        roster_list.append(df_row)
        
    roster_df = pd.DataFrame.from_records(roster_list,
                                          columns = ['player_name', 'team_name',
                                                     'positions', 'injury_status'])
    
    roster_df.insert(1, 'owning_team', owning_team)
    
    return(roster_df)

get_yahoo_roster(yahoo_oauth = oauth, team_name = "402.l.1157.t.12")
# Out:
# [2021-03-11 11:19:03,778 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 500.1529219150543
# [2021-03-11 11:19:03,782 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
#           player_name      owning_team               team_name  \
# 0      Damian Lillard  Dame of Thrones  Portland Trail Blazers
# 1        Shake Milton  Dame of Thrones      Philadelphia 76ers
# 2           John Wall  Dame of Thrones         Houston Rockets
# 3        Delon Wright  Dame of Thrones         Detroit Pistons
# 4         Paul George  Dame of Thrones    Los Angeles Clippers
# 5        Josh Jackson  Dame of Thrones         Detroit Pistons
# 6     Lauri Markkanen  Dame of Thrones           Chicago Bulls
# 7       Kyle Anderson  Dame of Thrones       Memphis Grizzlies
# 8        Theo Maledon  Dame of Thrones   Oklahoma City Thunder
# 9        Jakob Poeltl  Dame of Thrones       San Antonio Spurs
# 10  De'Anthony Melton  Dame of Thrones       Memphis Grizzlies
# 11        Mike Conley  Dame of Thrones               Utah Jazz
# 12         Joe Ingles  Dame of Thrones               Utah Jazz
# 13      Anthony Davis  Dame of Thrones      Los Angeles Lakers
# 14         Kevin Love  Dame of Thrones     Cleveland Cavaliers
# 15      Fred VanVleet  Dame of Thrones         Toronto Raptors
# 16         OG Anunoby  Dame of Thrones         Toronto Raptors
#
#                             positions injury_status
# 0                       [PG, G, Util]          NONE
# 1                   [PG, SG, G, Util]          NONE
# 2                       [PG, G, Util]          NONE
# 3   [PG, SG, G, SF, F, Util, IL, IL+]           INJ
# 4                   [SF, PF, F, Util]          NONE
# 5                [SG, G, SF, F, Util]          NONE
# 6           [PF, F, C, Util, IL, IL+]           INJ
# 7                   [SF, PF, F, Util]          NONE
# 8                       [PG, G, Util]          NONE
# 9                           [C, Util]          NONE
# 10                  [PG, SG, G, Util]          NONE
# 11                      [PG, G, Util]          NONE
# 12               [SG, G, SF, F, Util]          NONE
# 13          [PF, F, C, Util, IL, IL+]           INJ
# 14          [PF, F, C, Util, IL, IL+]           INJ
# 15         [PG, SG, G, Util, IL, IL+]           INJ
# 16         [SF, PF, F, Util, IL, IL+]           INJ

# %%
league_json = get_yahoo_league_info(yahoo_oauth = oauth,
                                    path_to_private = private_path,
                                    game_key = my_game_key,
                                    league_id = "1157")
number_of_teams = league_json["fantasy_content"]["league"][0]["num_teams"]
number_of_teams
# Out:
# [2021-03-11 11:14:52,843 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 249.2178030014038
# [2021-03-11 11:14:52,849 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# 12

# %%
# This is the url for a team's roster
# We should be able to loop through the total number of teams and then just cache
# a dataframe of the players and roster size
# We could consider having users enter a specific team so that you don't load
# all teams if you just want to update your matchup
# https://fantasysports.yahooapis.com/fantasy/v2/team/402.l.1157.t.1/roster/players

# %%
# To do:

# Function that gets df for a given player name

# Function that obtains how many times a player plays in a given
# week

# Use the season average and multiply it by the number of games
# played in a week to get the projected stat

# Function that gets dictionary between team code and team name
